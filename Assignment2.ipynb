# %%
import random
import numpy
from matplotlib import pyplot

# %%
def show(filename):
    data = numpy.loadtxt(filename)
    pyplot.hist(data)
    pyplot.show()

# %%
x = pl.rand(1000)

# %%
show(x)
